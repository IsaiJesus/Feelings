# %% [markdown]
# # Objetivos con el Dataset de sentimientos obtenido de la aplicación Daylio
#
# Con la información de las actividades, estas se pueden dividir por grupos, entre las cuales se podrían encontrar el sueño, condiciones cognitivas, ejercicio o actividad física, alimentación, educación, ocio, objetivos personales, tareas en casa, cuidado personal, entre otras.
#
# El objetivo principal del proyecto es conocer **cómo influyen las actividades diarias en los estados emocionales** y viceversa. Además de **cómo afectan otros factores externos a una persona en sí, como la escuela, alimentación, sueño, entre otros, especificamente en las emociones de un adolescente**.
#
# Algunas cuestiones que se pueden responder a lo largo del proyecto son:
#
# - Análisis visual con graficas de tiempo (días de la semana, mes, año), así como en la contabilización de actividades y emociones.
# - Relación de actividades con emociones positivas y negativas.
#     - Clasificar las actividades en función del impacto emocional (positivo, neutral o negativo) y crear un índice que mida qué tan influyentes son ciertas actividades en el estado emocional diario.
#     - Encontrar rutinas positivas o negativas analizando combinaciones frecuentes de actividades y emociones (análisis de asociaciones, como en reglas de mercado).
# - Relación entre la sencación de descanso con la emoción.
# - Relación entre productividad con las emociones.
# - Influencia de actividades con emociones en patrones temporales.
#
# Una vez observado cada comportamiento y detalle sobre cómo influyen las actividades y otras características en las emociones diarias, se tendrá el objetivo de crear modelos de Machine Learning a partir de lo siguiente:
#
# - Predicción de emoción.
# - Predicción de cantidad de actividades.
# - Algoritmo de agrupamiento para reconocer patrones.
# - Recomendación de actividades ante situaciones adversas.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv('../data/raw/1ene2024_25jun2024.csv')
df2 = pd.read_csv('../data/raw/10ago2024_04abr2025.csv')

# %%
df1.head()
# Out:
#     full_date     date   weekday      time  mood  \
# 0  2024-06-25  June 25   Tuesday  10:18 AM  Bien
# 1  2024-06-24  June 24    Monday   8:00 PM  Bien
# 2  2024-06-23  June 23    Sunday   8:00 PM  Bien
# 3  2024-06-22  June 22  Saturday   8:00 PM  Bien
# 4  2024-06-21  June 21    Friday   8:00 PM  Bien
#
#                                           activities  note_title  note
# 0  Feliz | Relajado | Contento | Cansado | Ocupad...         NaN   NaN
# 1  Contento | Ocupado | Confundido | Buen sueño |...         NaN   NaN
# 2  Feliz | Relajado | Contento | Motivado | Produ...         NaN   NaN
# 3  Feliz | Relajado | Contento | Cansado | Motiva...         NaN   NaN
# 4  Relajado | Contento | Ansioso | Decepcionado |...         NaN   NaN

# %%
df2.head()
# Out:
#     full_date    date    weekday        time       mood  \
# 0  2025-04-04   4 Apr     Friday  10:45 p.m.       Bien
# 1  2025-04-03   3 Apr   Thursday   2:12 p.m.       Bien
# 2  2025-04-02   2 Apr  Wednesday   2:12 p.m.       Bien
# 3  2025-04-01   1 Apr    Tuesday  10:45 p.m.       Bien
# 4  2025-03-31  31 Mar     Monday  10:45 p.m.  Increíble
#
#                                           activities  note_title  note
# 0  Sueño medio | Feliz | Contento | Ansioso | Est...         NaN   NaN
# 1  Sueño medio | Feliz | Relajado | Contento | Sa...         NaN   NaN
# 2    Sueño medio | Productivo | Proyecto | Skin care         NaN   NaN
# 3  Sueño malo | Relajado | Contento | Productivo ...         NaN   NaN
# 4  Buen sueño | Feliz | Relajado | Contento | Pro...         NaN   NaN

# %% [markdown]
# # Data cleaning

# %% [markdown]
# Antes de comenzar el análisis exploratorio, vamos a arreglar los DataFrames, ya que vienen en formatos diferentes, específicamente para el caso de `time` y `date`, además de que no se necesita de las columnas `note_title` ni `note`.
# También eliminar temporalmente los datos del 2025, ya que podrían darse errores de desproporcionalidad.

# %%
df1 = df1.drop(columns=['date', 'note_title', 'note'])
df2 = df2.drop(columns=['date', 'note_title', 'note'])

# %%
# Convertir el formato de 'time' en df2 al formato AM - PM
df2['time'] = df2['time'].str.replace(r'\.m\.', 'M', regex=True).str.replace(r'a', 'A', regex=True).str.replace(r'p', 'P', regex=True)

# %%
df2_filtered = df2[df2['full_date'] <= '2024-12-31']

# %%
# Por defecto axis=0
df = pd.concat([df2_filtered, df1])

# %%
df.head()
# Out:
#      full_date   weekday      time  mood  \
# 94  2024-12-31   Tuesday  10:45 PM  Bien
# 95  2024-12-30    Monday  11:10 PM  Bien
# 96  2024-12-29    Sunday  11:03 PM  Bien
# 97  2024-12-28  Saturday  10:33 PM  Bien
# 98  2024-12-27    Friday  11:56 PM  Bien
#
#                                            activities
# 94  Buen sueño | Feliz | Emocionado | Relajado | C...
# 95  Buen sueño | Feliz | Relajado | Contento | Pro...
# 96  Buen sueño | Feliz | Relajado | Contento | Pro...
# 97  Buen sueño | Relajado | Contento | Productivo ...
# 98  Buen sueño | Feliz | Relajado | Contento | Pro...

# %%
df.tail()
# Out:
#       full_date    weekday     time  mood  \
# 172  2024-01-05     Friday  7:14 PM  Bien
# 173  2024-01-04   Thursday  9:36 PM  Bien
# 174  2024-01-03  Wednesday  7:26 PM  Bien
# 175  2024-01-02    Tuesday  8:17 PM  Bien
# 176  2024-01-01     Monday  1:56 PM   Meh
#
#                                             activities
# 172  Cansado | Aburrido | Ansioso | Sueño medio | E...
# 173  Feliz | Relajado | Buen sueño | Ejercicio | Co...
# 174  Feliz | Contento | Buen sueño | Ejercicio | Ag...
# 175  Feliz | Relajado | Contento | Sueño medio | Ej...
# 176                  Relajado | Aburrido | Sueño medio

# %% [markdown]
# # Exploratory Data Analysis & Preprocessing

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 300 entries, 94 to 176
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   full_date   300 non-null    object
#  1   weekday     300 non-null    object
#  2   time        300 non-null    object
#  3   mood        300 non-null    object
#  4   activities  300 non-null    object
# dtypes: object(5)
# memory usage: 14.1+ KB

# %%
df.describe(include=['O'])
# Out:
#          full_date  weekday      time  mood  \
# count          300      300       300   300
# unique         300        7       189     5
# top     2024-12-31  Tuesday  10:45 PM  Bien
# freq             1       44        29   227
#
#                                                activities
# count                                                 300
# unique                                                300
# top     Buen sueño | Feliz | Emocionado | Relajado | C...
# freq                                                    1

# %% [markdown]
# ## Visualizaciones y Estadísticas

# %%
import calendar
import locale

# %%
locale.setlocale(locale.LC_TIME, 'es_MX.UTF-8')

# Asignar un color a cada tipo de emoción
mood_data = {
    'Horrible': 'crimson',
    'Mal': 'orange',
    'Meh': 'skyblue',
    'Bien': 'limegreen',
    'Increíble': 'turquoise'
}

# Convertir full_date a tipo datetime para extraer fácilmente el mes
df['full_date'] = pd.to_datetime(df['full_date'], errors='coerce')

# Extraer el mes con tipo numérico
df['month'] = df['full_date'].dt.month

moods_sorted = list(mood_data.keys())

# Columna para convertir moods a números ordenados (1: Terrible a 5: Increíble)
mapped_order = {mood: i for i, mood in enumerate(moods_sorted, start=1)}
df['mood_numeric'] = df['mood'].map(mapped_order)

# Columna para asignar colores en base al mood
df['colors'] = df['mood'].map(mood_data)

# %%
import matplotlib.dates as mdates

x = df['full_date']
y = df['mood_numeric']

plt.figure(figsize=(12, 6))

plt.plot(x, y, c='gainsboro', zorder=1)
plt.scatter(x, y, c=df['colors'], s=12, zorder=2)

plt.xlabel("Días del año")
plt.ylabel("Mood")
# Reemplazar números por categorías originales
plt.yticks(ticks=range(1, len(mood_data) + 1), labels=moods_sorted) 
unique_months = df['full_date'].dt.to_period('M').unique()
plt.xticks(ticks=unique_months, labels=[month.strftime('%b').capitalize() for month in unique_months])

plt.title("Emociones durante 2024-2025")

plt.show()

# %%
fig, axes = plt.subplots(4, 3, figsize=(15, 10))

axes = axes.flatten()

for month in range(1, 13):
    ax = axes[month - 1]  # Seleccionar el subgráfico correspondiente
    df_month = df[df['month'] == month]  # Filtrar los datos del mes actual

    ax.scatter(df_month['full_date'], df_month['mood_numeric'], c=df_month['colors'], s=12, zorder=2)
    ax.plot(df_month['full_date'], df_month['mood_numeric'], c='gainsboro', zorder=1)

    ax.set_title(f'{calendar.month_name[month].capitalize()}')
    ax.set_yticks(range(1, len(mood_data) + 1))  # Reemplazar números por las categorías originales
    ax.set_yticklabels(moods_sorted)
    ax.set_xticks([])

fig.suptitle("Emociones anuales por mes", fontsize=16)
plt.tight_layout()

plt.show()

# %%
sum_moods = df['mood'].value_counts()
moods = sum_moods.index

colors = [mood_data[mood] for mood in moods]

plt.pie(
    sum_moods, 
    labels=moods,
    colors=colors,
    textprops=dict(color="w")
)

handles = [plt.Line2D([0], [0], marker='o', color=color, markersize=10, linestyle='') 
           for color in colors]
labels = [f"{mood}: {sum_moods[mood]}" for mood in moods]
plt.legend(handles, labels, title="Moods", loc='upper right')

plt.title("Cantidad de emociones anual")
plt.text(0, 1.15, f'Total: {df.shape[0]}', ha='center', fontsize=12)

plt.show()

# %%
plt.bar(sum_moods.index, sum_moods.values)  
plt.xlabel('Emoción')
plt.ylabel('Frecuencia') 
plt.title('Frecuencia de emociones durante el año')

plt.show()

# %%
mean_month = df.groupby('month')['mood_numeric'].mean()

max_value = mean_month.max()
min_value = mean_month.min()

max_index = mean_month.idxmax()
min_index = mean_month.idxmin()

colors = ['green' if i == max_index else 'red' if i == min_index else 'C0' for i in mean_month.index]

bars = plt.bar([calendar.month_name[i].capitalize() for i in mean_month.index], mean_month.values, color=colors)

plt.bar_label(bars, labels=[f'{val:.2f}' for val in mean_month.values])

plt.ylabel('Promedio')
plt.title('Promedio por mes')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Para las estadísticas mensuales, y en general, se tiene que considerar que __no hay datos del mes de julio__ y __sólo uno en el mes de agosto__. Por lo cual para el siguiente gráfico se considera el promedio a partir de la cantidad total de días
# por mes.
#
# Esto ya que en la anterior al haber sólo un registro hecho en agosto (Increíble) hace parecer que es el mes con el promedio más alto.

# %%
# Cantidad de registros por mes
size_month = pd.Series({1: 31, 2: 29, 3: 31, 4: 30, 5: 31, 6: 30, 7: 31, 8: 31, 9: 30, 10: 31, 11: 30, 12: 31})

# Suma de valores de mood por mes
sum_month = df.groupby('month')['mood_numeric'].sum()
    
mean_month = sum_month / size_month
mean_month = mean_month.fillna(0)

max_value = mean_month.max()
# min_value = mean_month.min()

max_index = mean_month.idxmax()
# min_index = mean_month.idxmin()

colors = ['green' if i == max_index else 'red' if i == 6 else 'C0' for i in mean_month.index]

bars = plt.bar([calendar.month_name[i].capitalize() for i in mean_month.index], mean_month.values, color=colors)

plt.bar_label(bars, labels=[f'{val:.2f}' for val in mean_month.values])

plt.ylabel('Promedio')
plt.title('Promedio por mes')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Con la gráfica anterior se puede concluir que el mes con **mejor mood** fue en **abril**, mientras que el que tiene el **peor mood** (sin tomar en cuenta a julio y agosto por la cantidad de registros) fue **junio**.
# <br>
# E incluso a pesar de lo anterior, se debe tomar en cuenta que en el mes de **septiembre** fue el mes con más moods de **Increíble**, mientras que **febrero** y **mayo** fueron los únicos meses con el mood de **Horrible** como se muestra en la siguiente tabla.

# %%
df.groupby(['month', 'mood']).size().unstack(fill_value=0)
# Out:
# mood   Bien  Horrible  Increíble  Mal  Meh
# month
# 1        26         0          0    1    4
# 2        20         1          0    3    5
# 3        26         0          0    1    4
# 4        25         0          0    0    5
# 5        22         1          1    1    6
# 6        22         0          0    0    3
# 8         0         0          1    0    0
# 9        18         0          3    0    9
# 10       25         0          0    1    5
# 11       22         0          0    2    6
# 12       21         0          1    3    6

# %%
mean_weekday = df.groupby('weekday')['mood_numeric'].mean()

days_translation = {
    'Monday': 'Lunes',
    'Tuesday': 'Martes',
    'Wednesday': 'Miércoles',
    'Thursday': 'Jueves',
    'Friday': 'Viernes',
    'Saturday': 'Sábado',
    'Sunday': 'Domingo'
}

mean_weekday.index = mean_weekday.index.map(days_translation)

days_order = ['Lunes', 'Martes', 'Miércoles', 'Jueves', 'Viernes', 'Sábado', 'Domingo']

mean_weekday = mean_weekday.reindex(days_order)  # Reordenar días

max_value = mean_weekday.max()
min_value = mean_weekday.min()

max_index = mean_weekday.idxmax()
min_index = mean_weekday.idxmin()

colors = ['green' if i == max_index else 'red' if i == min_index else 'C0' for i in mean_weekday.index]

bars = plt.bar(mean_weekday.index, mean_weekday.values, color=colors)

plt.bar_label(bars, labels=[f'{val:.2f}' for val in mean_weekday.values])

plt.ylabel('Promedio')
plt.title('Promedio semanal')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Esta anterior gráfica representa igualmente el promedio del mood por día de la semana a lo largo del año, donde se muestra que el día con **mejor** mood ha sido el **sábado**, mientras que el que ha tenido **peor** fue el *miércoles**.

# %%
df['activities_count'] = df['activities'].apply(lambda x: len(x.split(' | ')))

# %%
df.head()
# Out:
#     full_date   weekday      time  mood  \
# 94 2024-12-31   Tuesday  10:45 PM  Bien
# 95 2024-12-30    Monday  11:10 PM  Bien
# 96 2024-12-29    Sunday  11:03 PM  Bien
# 97 2024-12-28  Saturday  10:33 PM  Bien
# 98 2024-12-27    Friday  11:56 PM  Bien
#
#                                            activities  month  mood_numeric  \
# 94  Buen sueño | Feliz | Emocionado | Relajado | C...     12             4
# 95  Buen sueño | Feliz | Relajado | Contento | Pro...     12             4
# 96  Buen sueño | Feliz | Relajado | Contento | Pro...     12             4
# 97  Buen sueño | Relajado | Contento | Productivo ...     12             4
# 98  Buen sueño | Feliz | Relajado | Contento | Pro...     12             4
#
#        colors  activities_count
# 94  limegreen                12
# 95  limegreen                11
# 96  limegreen                11
# 97  limegreen                 8
# 98  limegreen                 9

# %%
df['activities_count'].describe()
# Out:
# count    300.000000
# mean       9.360000
# std        3.059674
# min        2.000000
# 25%        7.000000
# 50%        9.000000
# 75%       11.000000
# max       21.000000
# Name: activities_count, dtype: float64

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

axes[0].hist(df['activities_count'], edgecolor='black')
axes[0].set_title("Cantidad de actividades")

axes[1].hist(df['mood_numeric'], edgecolor='black', bins=5)
axes[1].set_title("Moods")

plt.tight_layout()
plt.show()

# %%
plt.scatter(df['activities_count'], df['mood_numeric'])
plt.title('Cantidad de actividades vs. Mood')
plt.xlabel('Cantidad de actividades')
plt.ylabel('Mood')

plt.show()

# %%
df = df.drop('colors', axis=1)

# %%
# Todas las actividades en el dataset

# Set para evitar duplicados
activities = set()
df['activities'].str.split('|').apply(lambda x: activities.update([activity.strip() for activity in x]))
activities = list(activities)
activities
# Out:
# ['Clases completas',
#  'Ejercicio',
#  'Ansioso',
#  'Agua',
#  'Viaje',
#  'Enfocado',
#  'Motivado',
#  'Inglés',
#  'Estresado',
#  'Examen',
#  'Enfermo',
#  'Cocinar',
#  'Buen sueño',
#  'Sin dormir',
#  'Reunión',
#  'Enojado',
#  'Algoritmos',
#  'Triste',
#  'Evento',
#  'Pensativo',
#  'Skin care',
#  'Compras',
#  'Emocionado',
#  'Desmotivado',
#  'Sueño malo',
#  'Limpiar',
#  'Lectura',
#  'Vacaciones',
#  'Entretenimiento',
#  'Aburrido',
#  'Proyecto',
#  'Salida',
#  'IA & Data',
#  'Doctor',
#  'Competencia',
#  'Correr / Cardio',
#  'Comer sano',
#  'Protector solar',
#  'Visita',
#  'Productivo',
#  'Ocupado',
#  'Confundido',
#  'Iniciar temprano',
#  'Preocupado',
#  'Cansado',
#  'Clase',
#  'Haircut',
#  'Sueño medio',
#  'Miedo',
#  'Relajado',
#  'Contento',
#  'Hacer deberes',
#  'Enamorado',
#  'Sueño temprano',
#  'Procrastinar',
#  'Nostálgico',
#  'Estudio',
#  'Decepcionado',
#  'Feliz',
#  'Desesperado',
#  'Inseguro',
#  'Tarea',
#  'Proyecto grupal']

# %%
len(activities)
# Out:
# 63

# %% [markdown]
# Asignar una categoría ordinal para el sleep_level donde:
# - Sin dormir: 0
# - Sueño malo: 1
# - Sueño medio: 2
# - Sueño bueno: 3
# - Sueño temprano: 4
#
# Target Encoding para emotions. Luego, para positive, neutral y negative emotions, asignar la cantidad de emociones que se encuentren en un registro de ese tipo.
# Para el resto de registros, igualmente asignar valores a partir de Target Encoding.

# %%
sleep_level = {
    'Sin dormir': 0,
    'Sueño malo': 1,
    'Sueño medio': 2,
    'Buen sueño': 3,
    'Sueño temprano': 4
}

def get_sleep_level(activity):
    for key, value in sleep_level.items():
        if key in activity:
            return value
    return np.nan

df['sleep_level'] = df['activities'].apply(get_sleep_level)

# %%
# Lista de actividades que sí quieres usar para el encoding
emotions = [
    "Feliz", "Emocionado", "Enamorado", "Relajado", "Contento", "Cansado", "Inseguro", "Aburrido", "Ansioso",
    "Procrastinar", "Enojado", "Estresado", "Triste", "Desesperado", "Productivo", "Ocupado", "Confundido", 
    "Motivado", "Decepcionado" ,"Enfermo", "Desmotivado", "Miedo", "Pensativo", "Preocupado", "Nostálgico"
]

health = [
    "Ejercicio", "Comer sano", "Agua", "Correr / Cardio", "Doctor", "Haircut", "Skin care", "Protector solar"
]

productivity = [
    "Lectura", "Entretenimiento", "Iniciar temprano", "Enfocado", "Inglés", "IA & Data", "Algoritmos", 
    "Reunión", "Proyecto"
]

places = ["Visita", "Salida", "Viaje", "Vacaciones", "Competencia", "Evento"]

tasks = ["Compras", "Limpiar", "Cocinar", "Hacer deberes"]

school = ["Clase", "Estudio", "Tarea", "Examen", "Proyecto grupal", "Clases completas"]

# %%
def target_encode_group(df, target_activities, col_name):
    # Separar actividades si no se ha hecho
    if 'activity_list' not in df.columns:
        df['activity_list'] = df['activities'].str.split(' \| ')

    # Explode para contar individualmente
    exploded = df.explode('activity_list')

    # Filtrar solo las actividades objetivo
    filtered = exploded[exploded['activity_list'].isin(target_activities)]

    # Calcular media por actividad
    mean_target = filtered.groupby('activity_list')['mood_numeric'].mean()

    # Función para aplicar promedio de encoding solo a actividades válidas
    def encode(row):
        valid = [a for a in row['activity_list'] if a in target_activities]
        values = [mean_target.get(a, np.nan) for a in valid]
        return np.mean(values) if values else np.nan

    # Aplicar la función al DataFrame original
    df[col_name] = df.apply(encode, axis=1)

    return df

# %%
target_vars = ['emotions', 'health', 'productivity', 'places', 'tasks', 'school']

# Aplicar encoding a cada variable objetivo
for var_name in target_vars:
    activities = globals()[var_name]
    col_name = f"{var_name}_encoded"
    df = target_encode_group(df, activities, col_name)

df = df.drop(columns=['activity_list'])

# %%
# Separar en positive emotions, negative emotions y neutral_emotions
positive_emotions = [
    "Feliz", "Emocionado", "Enamorado", "Relajado", "Contento", "Productivo", "Motivado"
]

neutral_emotions = ["Ocupado", "Pensativo", "Confundido", "Nostálgico"]

negative_emotions = [
    "Cansado", "Inseguro", "Aburrido", "Ansioso", "Procrastinar", "Enojado", "Estresado", "Triste", 
    "Desesperado", "Decepcionado", "Enfermo", "Desmotivado", "Miedo",  "Preocupado"
]

# %%
df['activity_list'] = df['activities'].str.split(' \| ')

# Lista de nombres de las variables a contar
vars_to_count = ['positive_emotions', 'neutral_emotions', 'negative_emotions']

# Función para contar actividades
def count_activities(df, target_activities, col_name):
    def count(row):
        return sum(1 for a in row['activity_list'] if a in target_activities)
    df[col_name] = df.apply(count, axis=1)
    return df

# Aplicar la función para cada variable
for var_name in vars_to_count:
    activities = globals()[var_name]
    df = count_activities(df, activities, var_name)

# (Opcional) eliminar columna auxiliar
df = df.drop(columns=['activity_list'])
# Out:
#     full_date   weekday      time  mood  \
# 94 2024-12-31   Tuesday  10:45 PM  Bien
# 95 2024-12-30    Monday  11:10 PM  Bien
# 96 2024-12-29    Sunday  11:03 PM  Bien
# 97 2024-12-28  Saturday  10:33 PM  Bien
# 98 2024-12-27    Friday  11:56 PM  Bien
#
#                                            activities  month  mood_numeric  \
# 94  Buen sueño | Feliz | Emocionado | Relajado | C...     12             4
# 95  Buen sueño | Feliz | Relajado | Contento | Pro...     12             4
# 96  Buen sueño | Feliz | Relajado | Contento | Pro...     12             4
# 97  Buen sueño | Relajado | Contento | Productivo ...     12             4
# 98  Buen sueño | Feliz | Relajado | Contento | Pro...     12             4
#
#     activities_count  sleep_level  emotions_encoded  health_encoded  \
# 94                12          3.0          3.766775             NaN
# 95                11          3.0          3.922506             NaN
# 96                11          3.0          3.922506        3.820312
# 97                 8          3.0          3.903132             NaN
# 98                 9          3.0          3.903132             NaN
#
#     productivity_encoded  places_encoded  tasks_encoded  school_encoded  \
# 94              3.844444        3.833333            NaN             NaN
# 95              3.730472             NaN            NaN             NaN
# 96              3.882145             NaN            NaN        3.846154
# 97              3.824861             NaN            NaN             NaN
# 98              3.701979             NaN            NaN             NaN
#
#     positive_emotions  neutral_emotions  negative_emotions
# 94                  6                 1                  2
# 95                  5                 0                  0
# 96                  5                 0                  0
# 97                  4                 0                  0
# 98                  4                 0                  0

# %%
import re

def convert_float(hora_str):
    match = re.match(r'(\d{1,2}):(\d{2})\s*(AM|PM)', hora_str.strip(), re.IGNORECASE)
    if match:
        hour = int(match.group(1))
        minutes = int(match.group(2))
        meridian = match.group(3).upper()

        # Formato 24 horas
        if meridian == 'PM' and hour != 12:
            hour += 12
        elif meridian == 'AM' and hour == 12:
            hour = 0

        # Convertir minutos a decimal
        decimal_hour = hour + minutes / 60
        return round(decimal_hour, 2)
    else:
        return None

df['time'] = df['time'].apply(convert_float)

# %%
weekday_map = {
    'Monday': 1,
    'Tuesday': 2,
    'Wednesday': 3,
    'Thursday': 4,
    'Friday': 5,
    'Saturday': 6,
    'Sunday': 7
}

df['weekday'] = df['weekday'].map(weekday_map)

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 4))

axes[0].hist(df['sleep_level'], edgecolor='black', bins=5)
axes[0].set_title("Calidad del sueño")

axes[1].boxplot(df['time'], vert=False)
axes[1].set_title("Distribución de horas")

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 4))

axes[0].hist(df['positive_emotions'], edgecolor='black', bins=7)
axes[0].set_title("Cantidad de emociones positivas")

axes[1].hist(df['neutral_emotions'], edgecolor='black', bins=3)
axes[1].set_title("Cantidad de emociones neutras")

axes[2].hist(df['negative_emotions'], edgecolor='black', bins=8)
axes[2].set_title("Cantidad de emociones negativas")

plt.tight_layout()
plt.show()

# %%
df['sleep_level'].fillna(df['sleep_level'].mode().iloc[0], inplace=True)

# %%
df.head()
# Out:
#     full_date  weekday   time  mood  \
# 94 2024-12-31        2  22.75  Bien
# 95 2024-12-30        1  23.17  Bien
# 96 2024-12-29        7  23.05  Bien
# 97 2024-12-28        6  22.55  Bien
# 98 2024-12-27        5  23.93  Bien
#
#                                            activities  month  mood_numeric  \
# 94  Buen sueño | Feliz | Emocionado | Relajado | C...     12             4
# 95  Buen sueño | Feliz | Relajado | Contento | Pro...     12             4
# 96  Buen sueño | Feliz | Relajado | Contento | Pro...     12             4
# 97  Buen sueño | Relajado | Contento | Productivo ...     12             4
# 98  Buen sueño | Feliz | Relajado | Contento | Pro...     12             4
#
#     activities_count  sleep_level  emotions_encoded  health_encoded  \
# 94                12          3.0          3.766775             NaN
# 95                11          3.0          3.922506             NaN
# 96                11          3.0          3.922506        3.820312
# 97                 8          3.0          3.903132             NaN
# 98                 9          3.0          3.903132             NaN
#
#     productivity_encoded  places_encoded  tasks_encoded  school_encoded  \
# 94              3.844444        3.833333            NaN             NaN
# 95              3.730472             NaN            NaN             NaN
# 96              3.882145             NaN            NaN        3.846154
# 97              3.824861             NaN            NaN             NaN
# 98              3.701979             NaN            NaN             NaN
#
#     positive_emotions  neutral_emotions  negative_emotions
# 94                  6                 1                  2
# 95                  5                 0                  0
# 96                  5                 0                  0
# 97                  4                 0                  0
# 98                  4                 0                  0

# %%
df.describe().T
# Out:
#                       count                 mean                  min  \
# full_date               300  2024-06-25 11:45:36  2024-01-01 00:00:00
# weekday               300.0             3.983333                  1.0
# time                  300.0            18.678967                  0.0
# month                 300.0             6.323333                  1.0
# mood_numeric          300.0             3.743333                  1.0
# activities_count      300.0                 9.36                  2.0
# sleep_level           300.0             2.293333                  0.0
# emotions_encoded      300.0              3.70484             3.067531
# health_encoded        198.0             3.848358             3.803599
# productivity_encoded  190.0             3.821128             3.333333
# places_encoded         63.0             3.808669                  3.5
# tasks_encoded         116.0             3.852173             3.782609
# school_encoded        124.0             3.808893             3.744186
# positive_emotions     300.0                 2.39                  0.0
# neutral_emotions      300.0             0.186667                  0.0
# negative_emotions     300.0             1.536667                  0.0
#
#                                       25%                  50%  \
# full_date             2024-03-15 18:00:00  2024-05-29 12:00:00
# weekday                               2.0                  4.0
# time                                 20.0               22.485
# month                                 3.0                  5.0
# mood_numeric                          4.0                  4.0
# activities_count                      7.0                  9.0
# sleep_level                           2.0                  2.0
# emotions_encoded                 3.579646             3.748245
# health_encoded                   3.820312             3.855254
# productivity_encoded             3.793743             3.837378
# places_encoded                   3.769231                  3.8
# tasks_encoded                    3.821129             3.859649
# school_encoded                   3.779988             3.820175
# positive_emotions                     1.0                  2.0
# neutral_emotions                      0.0                  0.0
# negative_emotions                     0.0                  1.0
#
#                                       75%                  max       std
# full_date             2024-10-17 06:00:00  2024-12-31 00:00:00       NaN
# weekday                               6.0                  7.0  2.015755
# time                              23.0275                23.98  7.565738
# month                                10.0                 12.0  3.780622
# mood_numeric                          4.0                  5.0  0.593264
# activities_count                     11.0                 21.0  3.059674
# sleep_level                           3.0                  4.0  0.776293
# emotions_encoded                 3.862535                  4.0  0.189689
# health_encoded                   3.874537             3.910156  0.025944
# productivity_encoded             3.865771             3.914894  0.079163
# places_encoded                        4.0                  4.0  0.162286
# tasks_encoded                    3.869716             3.918919  0.034781
# school_encoded                   3.846154             3.848485  0.040068
# positive_emotions                     3.0                  6.0  1.377519
# neutral_emotions                      0.0                  2.0  0.415207
# negative_emotions                     2.0                  7.0  1.486389

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 300 entries, 94 to 176
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   full_date             300 non-null    datetime64[ns]
#  1   weekday               300 non-null    int64
#  2   time                  300 non-null    float64
#  3   mood                  300 non-null    object
#  4   activities            300 non-null    object
#  5   month                 300 non-null    int32
#  6   mood_numeric          300 non-null    int64
#  7   activities_count      300 non-null    int64
#  8   sleep_level           300 non-null    float64
#  9   emotions_encoded      300 non-null    float64
#  10  health_encoded        198 non-null    float64
#  11  productivity_encoded  190 non-null    float64
#  12  places_encoded        63 non-null     float64
#  13  tasks_encoded         116 non-null    float64
#  14  school_encoded        124 non-null    float64
#  15  positive_emotions     300 non-null    int64
#  16  neutral_emotions      300 non-null    int64
#  17  negative_emotions     300 non-null    int64
# dtypes: datetime64[ns](1), float64(8), int32(1), int64(6), object(2)
# memory usage: 43.4+ KB

# %%
df.to_csv('../data/processed/moods_2024.csv', index=False)
